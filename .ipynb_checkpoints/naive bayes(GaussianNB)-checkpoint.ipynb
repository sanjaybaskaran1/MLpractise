# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install duckdb
# Out:
# Collecting duckdb
#   Using cached duckdb-1.1.3-cp312-cp312-win_amd64.whl.metadata (781 bytes)
# Using cached duckdb-1.1.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Installing collected packages: duckdb
# Successfully installed duckdb-1.1.3

# %%
import duckdb

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
duckdb.query("select distinct(time) from df")
# Out:
# ┌─────────────────────────┐
# │          time           │
# │ enum('lunch', 'dinner') │
# ├─────────────────────────┤
# │ Lunch                   │
# │ Dinner                  │
# └─────────────────────────┘

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
x = df[["total_bill","tip"]]
x.head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
y = df['time']
y
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 244, dtype: category
# Categories (2, object): ['Lunch', 'Dinner']

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder(handle_unknown = 'ignore')

# %%
x_encoded = encoder.fit_transform(df[["sex", "smoker"]])

# %%
x_encoded
# Out:
# <244x4 sparse matrix of type '<class 'numpy.float64'>'
# 	with 488 stored elements in Compressed Sparse Row format>

# %%
x_encoded.shape
# Out:
# (244, 4)

# %%
x = pd.concat([x, pd.DataFrame(x_encoded.toarray(), columns=encoder.get_feature_names_out())], axis=1)

# %%
x
# Out:
#      total_bill   tip  sex_Female  sex_Male  smoker_No  smoker_Yes
# 0         16.99  1.01         1.0       0.0        1.0         0.0
# 1         10.34  1.66         0.0       1.0        1.0         0.0
# 2         21.01  3.50         0.0       1.0        1.0         0.0
# 3         23.68  3.31         0.0       1.0        1.0         0.0
# 4         24.59  3.61         1.0       0.0        1.0         0.0
# ..          ...   ...         ...       ...        ...         ...
# 239       29.03  5.92         0.0       1.0        1.0         0.0
# 240       27.18  2.00         1.0       0.0        0.0         1.0
# 241       22.67  2.00         0.0       1.0        0.0         1.0
# 242       17.82  1.75         0.0       1.0        1.0         0.0
# 243       18.78  3.00         1.0       0.0        1.0         0.0
#
# [244 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test = train_test_split(x,y)

# %%
x_train
# Out:
#      total_bill   tip  sex_Female  sex_Male  smoker_No  smoker_Yes
# 84        15.98  2.03         0.0       1.0        1.0         0.0
# 154       19.77  2.00         0.0       1.0        1.0         0.0
# 166       20.76  2.24         0.0       1.0        1.0         0.0
# 120       11.69  2.31         0.0       1.0        1.0         0.0
# 12        15.42  1.57         0.0       1.0        1.0         0.0
# ..          ...   ...         ...       ...        ...         ...
# 36        16.31  2.00         0.0       1.0        1.0         0.0
# 5         25.29  4.71         0.0       1.0        1.0         0.0
# 17        16.29  3.71         0.0       1.0        1.0         0.0
# 94        22.75  3.25         1.0       0.0        1.0         0.0
# 241       22.67  2.00         0.0       1.0        0.0         1.0
#
# [183 rows x 6 columns]

# %%
y_train
# Out:
# 84      Lunch
# 154    Dinner
# 166    Dinner
# 120     Lunch
# 12     Dinner
#         ...
# 36     Dinner
# 5      Dinner
# 17     Dinner
# 94     Dinner
# 241    Dinner
# Name: time, Length: 183, dtype: category
# Categories (2, object): ['Lunch', 'Dinner']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_train_scaled
# Out:
# array([[-0.41149334, -0.70328534, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [ 0.03762924, -0.725944  , -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [ 0.15494622, -0.54467468, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        ...,
#        [-0.37475772,  0.5655999 , -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [ 0.3907652 ,  0.21816704,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [ 0.38128504, -0.725944  , -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ]])

# %%
x_test_scaled = scaler.transform(x_test)
x_test_scaled
# Out:
# array([[-0.35105732, -0.725944  , -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.60939168,  0.78463366,  1.31580518, -1.31580518, -1.2416387 ,
#          1.2416387 ],
#        [ 2.45507005,  1.33599451, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [ 0.023409  ,  0.02934483,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [ 0.31610894, -0.06128983,  1.31580518, -1.31580518, -1.2416387 ,
#          1.2416387 ],
#        [ 0.82448252, -1.10358842,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [ 0.07436486,  0.14263815, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.43637876, -0.55222757,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [ 2.28442717,  0.02934483, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [ 0.88017846,  0.11997949, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [ 1.82226937,  1.6683216 ,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [-0.63783216, -0.34829959, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-1.41520528, -0.725944  , -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [ 2.36619355,  3.48856768, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [ 0.54837286, -0.03107828,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [ 1.45254313,  1.16227808, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.65323742,  0.07466216, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.18515452, -0.725944  , -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [ 1.23212941,  1.64566293,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [-0.22070512, -0.24255915, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [ 1.29730551,  1.99309579, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-1.28840814, -0.78636711, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [ 2.50010081,  0.02934483, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [-0.74922404, -0.725944  , -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [ 0.76286148,  1.66076871, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [-1.40928018, -1.14890575, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.37120266,  1.01122031,  1.31580518, -1.31580518, -1.2416387 ,
#          1.2416387 ],
#        [-0.12116344,  0.02934483, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [ 0.2663381 ,  1.01122031, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.628352  , -0.725944  ,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [ 0.18457172,  0.40698924, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [ 0.1182106 ,  0.02934483, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-1.1734612 , -1.14135286, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.79543982, -0.71839112,  1.31580518, -1.31580518, -1.2416387 ,
#          1.2416387 ],
#        [-1.12724542, -1.05827109, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.19463468, -0.4691458 , -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.07968774,  0.02934483,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [ 3.06891041,  0.40698924, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [ 1.22620431,  0.93569143,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [-0.4150484 , -0.725944  , -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.86417098, -0.57488624, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [ 0.84581288,  0.33901325, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [-0.7646293 , -0.725944  ,  1.31580518, -1.31580518, -1.2416387 ,
#          1.2416387 ],
#        [ 2.20621585,  0.78463366, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.154344  ,  0.40698924,  1.31580518, -1.31580518, -1.2416387 ,
#          1.2416387 ],
#        [ 0.54600282,  0.48251813, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.40438322, -0.54467468, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-1.11184016, -0.85434311,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [ 3.71593133,  5.31636666, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [ 1.24160957,  1.59279271, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [ 0.57088824, -0.70328534, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [-0.80136492, -0.725944  , -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-1.043109  , -1.10358842,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [-0.13893874,  0.78463366, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-1.02888876, -1.12624709, -0.75999093,  0.75999093,  0.80538727,
#         -0.80538727],
#        [-0.46481924,  0.02934483, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [-1.38794982, -1.14890575, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [-0.87957624, -1.10358842, -0.75999093,  0.75999093, -1.2416387 ,
#          1.2416387 ],
#        [-0.28232616,  0.02934483,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727],
#        [-0.7646293 , -0.725944  ,  1.31580518, -1.31580518, -1.2416387 ,
#          1.2416387 ],
#        [-0.23492536,  0.40698924,  1.31580518, -1.31580518,  0.80538727,
#         -0.80538727]])

# %%
from sklearn.naive_bayes import GaussianNB

# %%
m1 = GaussianNB()
m1
# Out:
# GaussianNB()

# %%
m1.fit(x_train_scaled,y_train)
# Out:
# GaussianNB()

# %%
y_pred_m1 = m1.predict(x_test_scaled)
y_pred_m1
# Out:
# array(['Dinner', 'Dinner', 'Dinner', 'Lunch', 'Dinner', 'Lunch', 'Dinner',
#        'Lunch', 'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Dinner',
#        'Dinner', 'Lunch', 'Dinner', 'Dinner', 'Dinner', 'Dinner',
#        'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Dinner',
#        'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Lunch', 'Dinner',
#        'Dinner', 'Dinner', 'Lunch', 'Dinner', 'Dinner', 'Lunch', 'Dinner',
#        'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Lunch', 'Dinner',
#        'Dinner', 'Dinner', 'Dinner', 'Lunch', 'Dinner', 'Dinner',
#        'Dinner', 'Dinner', 'Lunch', 'Dinner', 'Dinner', 'Dinner',
#        'Dinner', 'Dinner', 'Lunch', 'Lunch', 'Lunch'], dtype='<U6')

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
classification_report_m1 = classification_report(y_pred_m1, y_test)
print("classification_report_m1: ","\n\n",classification_report_m1)
confusion_matrix_m1 = confusion_matrix(y_pred_m1, y_test)
print("confusion_matrix_m1: ","\n\n",confusion_matrix_m1)
# Out:
# classification_report_m1:
#
#                precision    recall  f1-score   support
#
#       Dinner       0.89      0.83      0.86        48
#        Lunch       0.50      0.62      0.55        13
#
#     accuracy                           0.79        61
#    macro avg       0.69      0.72      0.71        61
# weighted avg       0.81      0.79      0.79        61
#
# confusion_matrix_m1:
#
#  [[40  8]
#  [ 5  8]]

# %%
accuracy = accuracy_score(y_test, y_pred_m1)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.7868852459016393

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'var_smoothing': [1e-9, 1e-8, 1e-7]
}

grid_search = GridSearchCV(GaussianNB(), param_grid, cv=5)
grid_search.fit(x_train_scaled, y_train)

best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# %%
best_params
# Out:
# {'var_smoothing': 1e-09}

# %%
best_model
# Out:
# GaussianNB()

# %%
y_pred_grid_cv = grid_search.predict(x_test_scaled)

# %%
classification_report_y_pred_grid_cv = classification_report(y_pred_grid_cv, y_test)
print("classification_report_y_pred_grid_cv: ","\n\n",classification_report_y_pred_grid_cv)
confusion_matrix_y_pred_grid_cv = confusion_matrix(y_pred_grid_cv, y_test)
print("confusion_matrix_m1: ","\n\n",confusion_matrix_y_pred_grid_cv)
# Out:
# classification_report_y_pred_grid_cv:
#
#                precision    recall  f1-score   support
#
#       Dinner       0.89      0.83      0.86        48
#        Lunch       0.50      0.62      0.55        13
#
#     accuracy                           0.79        61
#    macro avg       0.69      0.72      0.71        61
# weighted avg       0.81      0.79      0.79        61
#
# confusion_matrix_m1:
#
#  [[40  8]
#  [ 5  8]]
